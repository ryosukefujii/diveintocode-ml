# %% [markdown]
# # 紙を折る
# 紙を折り続けると厚さが増していき、43回で月に届くという話があります。しかし、実際には10回も折ることができません。また、手計算も大変です。
#
#
# そこで今回の課題では 1枚の紙を43回折り曲げた時の厚さを計算するプログラム を作成します。
# 43回折った紙の厚さ $t_{43}$は、折る前の紙の厚さ$t_{0}$を使い以下の数式で求まります。
#
# $t_{43} = t_{0} × 2^{43}$
#
# 折る前の紙の厚さ$t_{0}$は**0.00008m**とします。一般的なコピー用紙の厚さです。

# %% [markdown]
# # 2つの方法による厚さの計算
# プログラミングでは同じ動作を様々な方法で記述することができます。今回は以下の2つを作成してください。
#
# * べき乗の算術演算子を使用
# * for文を使用

# %% [markdown]
# ## 【問題1】べき乗の算術演算子を使用して作成
# べき乗の算術演算子を使用したプログラムを作ってください。
# 雛形として紙を1回折った時の厚さを計算するコードを用意しました。これを43回折った時のコードに書き換えてください。

# %% [markdown]
# ###️ 《雛形》

# %%
"""
紙を1回折った時の厚さを計算するコード
"""

THICKNESS = 0.00008

folded_thickness = THICKNESS*2

print("厚さ： {}メートル".format(folded_thickness))

# %% [markdown]
# ### 【問題1】解答

# %%
THICKNESS = 0.00008 # 折る前の紙の厚さ
times = 43 # 折った回数
folded_thickness = THICKNESS*(2**times) # 折った後の紙の厚さ
print("厚さ： {}メートル".format(folded_thickness))
# Out:
# 厚さ： 703687441.77664メートル

# %% [markdown]
# ## 【問題2】単位の変換
# 単位がメートルだと実感が湧きづらいので、◯◯万キロメートル に変換して表示させてください。
#
# サンプルとして ◯◯キロメートル に変換したコードを用意したので、参考にして取り組んでください。小数点以下は2桁まで表示されるようにも指定しています。

# %% [markdown]
# ###《サンプルコード》

# %%
# メートルをキロメートルに変換して小数点以下2桁で表示する
print("厚さ： {:.2f}キロメートル".format(folded_thickness/1000))

# %% [markdown]
# 「月までの距離」を検索して、折った紙が月に届くかどうか確認してみましょう。

# %% [markdown]
# ### 【問題2】解答

# %%
THICKNESS = 0.00008 # 折る前の紙の厚さ
times = 43 # 折った回数
folded_thickness = THICKNESS*(2**times) # 折った後の紙の厚さ

# メートルをキロメートルに変換して小数点以下2桁で表示する
print("厚さ： {:.2f}万キロメートル".format(folded_thickness/10000000))
# 月までの距離
distance_to_moon = 384400*1000

if folded_thickness >= distance_to_moon:
  print('reached')
else:
  print('not reached')
# Out:
# 厚さ： 70.37万キロメートル
# reached

# %% [markdown]
# ## 【問題3】for文を使用して作成
# 次に、for文を使用したプログラムを作ってください。
#
# べき乗の算術演算子は使ってはいけません。算術演算子は四則演算（+、-、*、/）のみ使えます。
#
# 《ヒント》
#
# べき乗は以下のように掛け算の繰り返しに置き換えることができます。
#
# $ 2^{3} = 2 × 2 × 2 $
#
# $ 2^{5} = 2 × 2 × 2 × 2 × 2 $

# %% [markdown]
# ### 【問題3】解答

# %%
THICKNESS = 0.00008 # 折る前の紙の厚さ
times = 43 # 折った回数
folded_thickness = THICKNESS # 折った後の紙の厚さ

for i in range(times):
  folded_thickness = folded_thickness*2
print("厚さ： {:.2f}万キロメートル".format(folded_thickness/10000000)) # メートルをキロメートルに変換して小数点以下2桁で表示する
# Out:
# 厚さ： 70.37万キロメートル

# %% [markdown]
# ## 【問題4】計算時間の比較
# 2つの方法はどちらが正しいわけでもありませんが、コードの良さを評価する際には以下のような着目点があります。
#
# * 計算速度
# * メモリの使用量
# * 可読性
# * 拡張性
# * 再利用性
#
# 今回は計算速度を比較してみます。以下の雛形を使用して、2つの方法の計算時間を出力してください。そして、それぞれの計算時間の関係を簡単に説明してください。どちらの書き方が良さそうでしょうか。なお、変数の定義やprint文など、どちらの方法でも使われている部分は除いた範囲の時間を比較してください。

# %% [markdown]
# ### 《雛形》
# timeモジュールを用いることで現在の時間を取得できます。比較したい箇所の前後の時間の差を計算することで、実行時間を求めます。

# %%
import time
start = time.time()
#####
# ここに比較したいコードを貼り付ける
#####
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))

# %% [markdown]
# ### 【問題4】解答

# %% [markdown]
# #### TEST(べき乗)

# %%
import time
start = time.time()
#####
# ここに比較したいコードを貼り付ける

THICKNESS = 0.00008
times = 1000
folded_thickness = THICKNESS*(2**times)
# print("厚さ： {:.2f}万キロメートル".format(folded_thickness/10000000))

#####
elapsed_time = time.time() - start
print("time : {:.7f}[s]".format(elapsed_time))
# Out:
# time : 0.0000653[s]

# %% [markdown]
# #### TEST(べき乗/マジックコマンド)

# %%
# %%timeit
#####
# ここに比較したいコードを貼り付ける

THICKNESS = 0.00008
times = 1000
folded_thickness = THICKNESS*(2**times)
# print("厚さ： {:.2f}万キロメートル".format(folded_thickness/10000000))

#####
# Out:
# The slowest run took 5.11 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 3: 884 ns per loop

# %% [markdown]
# #### TEST(for文)

# %%
import time
start = time.time()
#####
# ここに比較したいコードを貼り付ける

THICKNESS = 0.00008
times = 1000
folded_thickness = THICKNESS

for i in range(times):
  folded_thickness = folded_thickness*2
# print("厚さ： {:.2f}万キロメートル".format(folded_thickness/10000000))

#####
elapsed_time = time.time() - start
print("time : {:.7f}[s]".format(elapsed_time))
# Out:
# time : 0.0001559[s]

# %% [markdown]
# #### TEST(for文/マジックコマンド)

# %%
# %%timeit
#####
# ここに比較したいコードを貼り付ける

THICKNESS = 0.00008
times = 1000
folded_thickness = THICKNESS

for i in range(times):
  folded_thickness = folded_thickness*2
# print("厚さ： {:.2f}万キロメートル".format(folded_thickness/10000000))

#####
# Out:
# 10000 loops, best of 3: 45.4 µs per loop

# %% [markdown]
# #過程の可視化
# 折り曲げた時の厚さを毎回記録しておき、それを折れ線グラフで可視化してみます。
#
# 数式を一般化し、n回折った紙の厚さ
# t
# n
#  は以下のように表せます。
#
# $ t_{n<}= t_{0} × 2^{n} $
#
# これは指数関数です。指数関数は値が急激に増加する性質があります。厚さが急激に増えて月に到達する様子をグラフで見てみましょう。

# %% [markdown]
# ## 【問題5】リストへの保存
# ここまでは43回折った後の最後の値だけを使用していましたが、グラフで可視化するためには過程の値も必要です。for文を使用したコードに、過程の値合計44個を記録するコードを加えてください。
#
# 《ヒント》
#
# * 空のリストを作成する。
# * 折る前の値をリストに追加する。
# * for文の中でn回折った時の値をリストに追加していく。
# 最終的にリストに44個の値が格納されていることをlen関数を用いて確認しておきましょう。

# %% [markdown]
# ### 【問題5】解答

# %%
THICKNESS = 0.00008 # 折る前の紙の厚さ
times = 43 # 折った回数
chart = [THICKNESS] # 折った回数毎の厚さのリスト

for i in range(times):
 chart.append(THICKNESS*2)
 THICKNESS = THICKNESS*2

print(chart)
# Out:
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192, 0.16384, 0.32768, 0.65536, 1.31072, 2.62144, 5.24288, 10.48576, 20.97152, 41.94304, 83.88608, 167.77216, 335.54432, 671.08864, 1342.17728, 2684.35456, 5368.70912, 10737.41824, 21474.83648, 42949.67296, 85899.34592, 171798.69184, 343597.38368, 687194.76736, 1374389.53472, 2748779.06944, 5497558.13888, 10995116.27776, 21990232.55552, 43980465.11104, 87960930.22208, 175921860.44416, 351843720.88832, 703687441.77664]

# %% [markdown]
# ## 【問題6】折れ線グラフの表示
# グラフの描画には Matplotlib という ライブラリ を用います。リストへ記録するコードの後ろで以下の雛形を使用してください。

# %% [markdown]
# ### 《雛形》

# %%
"""
グラフを表示する。タイトルと軸ラベル名付き。
"""
import matplotlib.pyplot as plt
# %matplotlib inline

plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.plot(リスト名) # 「リスト名」のところにリストの変数名を入れる
plt.show()

# %% [markdown]
# グラフを表示させた場合はそれに対する考察が重要です。厚さがどのように変化しているかを簡単に説明してください。

# %% [markdown]
# ### 【問題6】解答

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

THICKNESS = 0.00008 # 折る前の紙の厚さ
times = 43 # 折った回数
chart = [THICKNESS] # 折った回数毎の厚さのリスト

for i in range(times):
 chart.append(THICKNESS*2)
 THICKNESS = THICKNESS*2


sns.set()
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.plot(chart)
plt.show()

# %% [markdown]
# ## 【問題7】グラフのカスタマイズ
# グラフをより見やすくカスタマイズしてみましょう。カスタマイズしたグラフを最低3種類作成してください。例えば以下のように書き換えることで、線の色を赤に変更できます。

# %% [markdown]
# ### 《サンプルコード》

# %%
"""
赤い折れ線グラフを表示する。
"""
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.plot(リスト名, color='red')
plt.show()

# %% [markdown]
# どのようなことができるかはMatplotlibの公式ドキュメントを参考にします。
#
# [matplotlib.pyplot.plot — Matplotlib 3.0.2 documentation
# ](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html)
#
# **《カスタマイズ例》**
#
# 線の色を青と赤以外にする。
# 線を太くする。
# 線を点線にする。
# 値のフォントサイズを変更する。
# 上記のページに載っていないカスタマイズも可能です。

# %% [markdown]
# ### 《サンプルコード》

# %%
"""
軸の値を大きく表示する。
"""
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.tick_params(labelsize=20) # 軸の値に関する設定を行う
plt.plot(リスト名)
plt.show()

# %% [markdown]
# このplt.tick_params()に関しては以下のページで説明されています。
#
# [matplotlib.pyplot.tick_params — Matplotlib 2.1.1 documentation
# ](https://matplotlib.org/2.1.1/api/_as_gen/matplotlib.pyplot.tick_params.html)
#
# 様々なカスタマイズ方法を調べて見やすいグラフを作成しましょう。
#
# この課題への回答を分かりやすく綺麗なものにまとめられたら完成です。

# %% [markdown]
# ### 【問題7】解答

# %% [markdown]
# #### ①

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


THICKNESS = 0.00008 # 折る前の紙の厚さ
times = 43 # 折った回数
chart = [THICKNESS] # 折った回数毎の厚さのリスト

for i in range(times):
 chart.append(THICKNESS*2)
 THICKNESS = THICKNESS*2


sns.set()
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.tick_params(labelsize=10)
plt.plot(chart, color='red', linestyle='dashed')
plt.show()

# %% [markdown]
# #### ②

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


THICKNESS = 0.00008 # 折る前の紙の厚さ
times = 43 # 折った回数
chart = [THICKNESS] # 折った回数毎の厚さのリスト

for i in range(times):
 chart.append(THICKNESS*2)
 THICKNESS = THICKNESS*2


sns.set()
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.tick_params(labelsize=20)
plt.plot(chart, color='g', linewidth = 3.0, linestyle='-.')
plt.show()

# %% [markdown]
# #### ③

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

THICKNESS = 0.00008 # 折る前の紙の厚さ
times = 43 # 折った回数
chart = [THICKNESS] # 折った回数毎の厚さのリスト

sum = 1
for i in range(43):
 chart.append(THICKNESS)
 THICKNESS = THICKNESS * 2
chart.append(THICKNESS)
folded_thickness = THICKNESS


sns.set()
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.tick_params(labelsize=15)
plt.plot(chart, color='c', linewidth = 4.0, linestyle=':')
plt.show()
